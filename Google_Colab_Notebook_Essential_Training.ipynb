# %% [markdown]
# <a href="https://colab.research.google.com/github/BarryDeCicco/Google_Colab_Training_LinkedIn/blob/main/Google_Colab_Notebook_Essential_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# prompt: create a dataframe with 2 columns and 10 rows

import pandas as pd
import numpy as np

# Create a DataFrame with 2 columns and 10 rows
data = {'col1': np.random.rand(10), 'col2': np.random.randint(0, 100, 10)}
df_new = pd.DataFrame(data)
df_new
# Out:
#        col1  col2
# 0  0.623716    14
# 1  0.474742    14
# 2  0.419210    35
# 3  0.804160    27
# 4  0.003617    65
# 5  0.873762    65
# 6  0.920037    71
# 7  0.997578    51
# 8  0.646613    34
# 9  0.481034    49

# %%
# prompt: create a third column in the data frame above, let it be the value in column 1 multiplied by the values in column 2

df_new['col3'] = df_new['col1'] * df_new['col2']
df_new
# Out:
#   File "<ipython-input-12-1a82d754857b>", line 1
#     create a third colmun in the data frame above, let it be thte value in column 1 multiplie by the values in column 2
#            ^
# SyntaxError: invalid syntax

# %%
df2=pd.read_csv("/content/sample_data/california_housing_train.csv")
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# prompt: rename df to df_test and df2 to df_train

df_test = df
df_train = df2

# %%
df_california_housing = pd.concat([df_test, df_train])
df_california_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.05     37.37                27.0       3885.0           661.0
# 1        -118.30     34.26                43.0       1510.0           310.0
# 2        -117.81     33.78                27.0       3589.0           507.0
# 3        -118.36     33.82                28.0         67.0            15.0
# 4        -119.67     36.33                19.0       1241.0           244.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df_test['flag'] = 'test'
df_train['flag'] = 'train'

# %%
 df_california_housing = pd.concat([df_test, df_train])
 df_california_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.05     37.37                27.0       3885.0           661.0
# 1        -118.30     34.26                43.0       1510.0           310.0
# 2        -117.81     33.78                27.0       3589.0           507.0
# 3        -118.36     33.82                28.0         67.0            15.0
# 4        -119.67     36.33                19.0       1241.0           244.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# prompt: print row counts for: df_train, df_test

print("df_train row count:", len(df_train))
print("df_test row count:", len(df_test))
print(df_california_housing['flag'].value_counts())
# Out:
# df_train row count: 17000
# df_test row count: 3000
# flag
# train    17000
# test      3000
# Name: count, dtype: int64

# %% [markdown]
# ## Section 3:  File Management in Google Colab

# %% [markdown]
# ##### Working with files and file paths in Colab:

# %% [markdown]
# ##### Uploading and downloading files to Colab from a local machine:

# %% [markdown]
# **The video did not match what I saw in my notebook**

# %% [markdown]
# ##### Mounting and accessing Google Drive in Google Colab:

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# prompt: save df_california_housing to the 'Colab Notebooks' folder in my Google drive

df_california_housing.to_csv('/gdrive/My Drive/Colab Notebooks/df_california_housing.csv', index=False)
